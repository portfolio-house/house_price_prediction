# %%
# Ensure project root is in sys.path for imports
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# # 02 - Data Preprocessing
# This notebook covers the full preprocessing pipeline: loading, cleaning, feature engineering, splitting, and saving processed data.

# %%
import pandas as pd
import numpy as np
from src.data.preprocess import load_data, clean_data, select_features, split_data, save_processed_data

RAW_PATH = '../data/raw/train.csv'
PROCESSED_DIR = '../data/processed/'

# %%
df = load_data(RAW_PATH)
df.head()
# Out:
# INFO:src.data.preprocess:Data loaded successfully with 1460 rows
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
# ...

# %%
df_clean = clean_data(df)
df_clean.info()
# Out:
# INFO:src.data.preprocess:Data cleaning completed
# <class 'pandas.core.frame.DataFrame'>
# Index: 1455 entries, 0 to 1459
# Data columns (total 85 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1455 non-null   int64
#  1   MSSubClass     1455 non-null   object
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1455 non-null   float64
#  4   LotArea        1455 non-null   int64
#  5   Street         1455 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1455 non-null   object
#  8   LandContour    1455 non-null   object
#  9   Utilities      1455 non-null   object
#  10  LotConfig      1455 non-null   object
#  11  LandSlope      1455 non-null   object
#  12  Neighborhood   1455 non-null   object
#  13  Condition1     1455 non-null   object
#  14  Condition2     1455 non-null   object
#  15  BldgType       1455 non-null   object
# ...

# %%
X, y = select_features(df_clean)
X_train, X_test, y_train, y_test = split_data(X, y)
print('Train shape:', X_train.shape)
print('Test shape:', X_test.shape)
# Out:
# INFO:src.data.preprocess:Train shape: (1164, 8), Test shape: (291, 8)
# Train shape: (1164, 8)
# Test shape: (291, 8)

# %%
save_processed_data(pd.concat([X, y], axis=1), output_dir=PROCESSED_DIR)
# Out:
# INFO:src.data.preprocess:Saved processed data to ../data/processed//cleaned_20250731_1618.csv
# '../data/processed//cleaned_20250731_1618.csv'

# %%
import sys, os
sys.path.append(os.path.abspath(".."))
